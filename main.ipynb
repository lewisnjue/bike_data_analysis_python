# %%
import pandas as pd # importing the pandas library 
import numpy as np # importing numpy 
import matplotlib.pyplot as plt # for plotting

# %%
df = pd.read_csv('bike_sales_100k.csv') 
df.set_index('Sale_ID',inplace=True) # set the column sales_id as the index that is very important

# %%
df.head() # get the genral idia of how the data look like
# Out:
#                Date  Customer_ID     Bike_Model    Price  Quantity  \
# Sale_ID
# 1        11-07-2022         9390        Cruiser   318.32         1
# 2        03-05-2024         3374    Hybrid Bike  3093.47         4
# 3        01-09-2022         2689   Folding Bike  4247.99         3
# 4        28-09-2022         3797  Mountain Bike  1722.01         3
# 5        05-01-2021         1633            BMX  3941.44         3
#
#         Store_Location  Salesperson_ID Payment_Method  Customer_Age  \
# Sale_ID
# 1         Philadelphia             589      Apple Pay            70
# 2              Chicago             390      Apple Pay            37
# 3          San Antonio             338         PayPal            59
# 4          San Antonio             352      Apple Pay            19
# 5         Philadelphia             580         PayPal            67
#
#         Customer_Gender
# Sale_ID
# 1                Female
# 2                  Male
# 3                Female
# ...

# %%
df.info() # from my data there is no need o data clearning here
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100000 entries, 1 to 100000
# Data columns (total 10 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Date             100000 non-null  object
#  1   Customer_ID      100000 non-null  int64
#  2   Bike_Model       100000 non-null  object
#  3   Price            100000 non-null  float64
#  4   Quantity         100000 non-null  int64
#  5   Store_Location   100000 non-null  object
#  6   Salesperson_ID   100000 non-null  int64
#  7   Payment_Method   100000 non-null  object
#  8   Customer_Age     100000 non-null  int64
#  9   Customer_Gender  100000 non-null  object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 8.4+ MB

# %%
df.describe()
# Out:
#          Customer_ID          Price       Quantity  Salesperson_ID  \
# count  100000.000000  100000.000000  100000.000000   100000.000000
# mean     5495.450720    2598.182340       2.997110      549.906300
# std      2598.873948    1384.943133       1.414235      259.679221
# min      1000.000000     200.010000       1.000000      100.000000
# 25%      3249.000000    1399.787500       2.000000      324.000000
# 50%      5491.000000    2598.575000       3.000000      550.000000
# 75%      7738.000000    3795.982500       4.000000      775.000000
# max      9999.000000    4999.810000       5.000000      999.000000
#
#         Customer_Age
# count  100000.000000
# mean       44.043410
# std        15.313761
# min        18.000000
# 25%        31.000000
# 50%        44.000000
# 75%        57.000000
# max        70.000000

# %%
# LETS START OUR DATA CLEARNING FIRST

# %%
# null vaues  
df.isnull().sum()
# Out:
# Date               0
# Customer_ID        0
# Bike_Model         0
# Price              0
# Quantity           0
# Store_Location     0
# Salesperson_ID     0
# Payment_Method     0
# Customer_Age       0
# Customer_Gender    0
# dtype: int64

# %%
# since no null value lets go to the next step

# %%
# check for duplicates 
df.duplicated()
# Out:
# Sale_ID
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
#           ...
# 99996     False
# 99997     False
# 99998     False
# 99999     False
# 100000    False
# Length: 100000, dtype: bool

# %%
# since there are no duplicates lets go to the next step

# %%
df['Bike_Model'] = df['Bike_Model'].str.lower()

# %%
df.head()
# Out:
#                Date  Customer_ID     Bike_Model    Price  Quantity  \
# Sale_ID
# 1        11-07-2022         9390        cruiser   318.32         1
# 2        03-05-2024         3374    hybrid bike  3093.47         4
# 3        01-09-2022         2689   folding bike  4247.99         3
# 4        28-09-2022         3797  mountain bike  1722.01         3
# 5        05-01-2021         1633            bmx  3941.44         3
#
#         Store_Location  Salesperson_ID Payment_Method  Customer_Age  \
# Sale_ID
# 1         Philadelphia             589      Apple Pay            70
# 2              Chicago             390      Apple Pay            37
# 3          San Antonio             338         PayPal            59
# 4          San Antonio             352      Apple Pay            19
# 5         Philadelphia             580         PayPal            67
#
#         Customer_Gender
# Sale_ID
# 1                Female
# 2                  Male
# 3                Female
# ...

# %%
df['Store_Location'] = df['Store_Location'].str.lower()

# %%
df.head()
# Out:
#                Date  Customer_ID     Bike_Model    Price  Quantity  \
# Sale_ID
# 1        11-07-2022         9390        cruiser   318.32         1
# 2        03-05-2024         3374    hybrid bike  3093.47         4
# 3        01-09-2022         2689   folding bike  4247.99         3
# 4        28-09-2022         3797  mountain bike  1722.01         3
# 5        05-01-2021         1633            bmx  3941.44         3
#
#         Store_Location  Salesperson_ID Payment_Method  Customer_Age  \
# Sale_ID
# 1         philadelphia             589      Apple Pay            70
# 2              chicago             390      Apple Pay            37
# 3          san antonio             338         PayPal            59
# 4          san antonio             352      Apple Pay            19
# 5         philadelphia             580         PayPal            67
#
#         Customer_Gender
# Sale_ID
# 1                Female
# 2                  Male
# 3                Female
# ...

# %%
df['Payment_Method'] = df['Payment_Method'].str.lower()

# %%
df['Customer_Gender'] = df['Customer_Gender'].str.lower()

# %%
df.describe()
# Out:
#          Customer_ID          Price       Quantity  Salesperson_ID  \
# count  100000.000000  100000.000000  100000.000000   100000.000000
# mean     5495.450720    2598.182340       2.997110      549.906300
# std      2598.873948    1384.943133       1.414235      259.679221
# min      1000.000000     200.010000       1.000000      100.000000
# 25%      3249.000000    1399.787500       2.000000      324.000000
# 50%      5491.000000    2598.575000       3.000000      550.000000
# 75%      7738.000000    3795.982500       4.000000      775.000000
# max      9999.000000    4999.810000       5.000000      999.000000
#
#         Customer_Age
# count  100000.000000
# mean       44.043410
# std        15.313761
# min        18.000000
# 25%        31.000000
# 50%        44.000000
# 75%        57.000000
# max        70.000000

# %%
# let get to data analysis part of pandas 
"""
lets start drawing a historam of the data 
"""
# Out:
# '\nlets start drawing a historam of the data \n'

# %%
df.hist() # this is not relevant in this king of data
# Out:
# array([[<Axes: title={'center': 'Customer_ID'}>,
#         <Axes: title={'center': 'Price'}>],
#        [<Axes: title={'center': 'Quantity'}>,
#         <Axes: title={'center': 'Salesperson_ID'}>],
#        [<Axes: title={'center': 'Customer_Age'}>, <Axes: >]], dtype=object)

# %%
# find the correlation on the data 
age = df['Customer_Age']
quantity = df['Quantity']
corr = quantity.corr(age)
corr.round(2)
corr
# Out:
# np.float64(-2.0064837599954537e-05)

# %%
# that shows that there is no realtionship in customer_age with quantity order which is king of interesting 
price = df['Price']
price.corr(quantity)
# Out:
# np.float64(-0.00137644254515794)

# %%
# this also so there is no relationship price and quantity ordered
